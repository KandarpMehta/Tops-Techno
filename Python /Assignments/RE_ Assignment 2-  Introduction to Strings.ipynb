# %% [markdown]
# ## <u>While doing this assignment only use those concepts which have been taught till now</u>

# %% [markdown]
# ## <u>Problem 1</u>
#
# You are given a sentence which reads <b>"Wikipedia is a free online encyclopedia, created and edited by volunteers around the world and hosted by the Wikimedia Foundation."</b>
#
# Find the number of words in the given sentence.

# %%
# Store the given sentence in a variable
sentence = "Wikipedia is a free online encyclopedia, created and edited by volunteers around the world and hosted by the Wikimedia Foundation."

# %%
# Calculate the total number of words in the sentence.  Hint : Use the count() method
sentence = "Wikipedia is a free online encyclopedia, created and edited by volunteers around the world and hosted by the Wikimedia Foundation."

# %%
# Print the variable num_of_words
words=sentence.count(" ")
num_of_words=words+1
print(num_of_words)
# Out:
# 20

# %% [markdown]
# ## <u>Problem 2 </u>
#
# Write a Python code which takes a number and returns a corresponding string of hyphens. For example if the number is 3, it will return '---' , if the number is 5 it will return '-----'

# %%
# Store the user input in a variable
a=int(input("enter the number= "))
hyphens = '-' * a
print(hyphens)
# Out:
# enter the number= 5
# -----

# %%
# Create a string of equivalent number of hyphens. Hint : remember what happens when we multiply string by a number?

# %%
# Print the string of hyphens
# string_of_hyphens
a
# Out:
# '--------------------'

# %% [markdown]
# ## <u> Problem 3 </u>
#
# A string can be called a safe bridge if it has no gaps in it i.e, no spaces. You are supposed to take an input from the user and print whether the string is a safe bridge or not.

# %%
# Store the user input in a variable
a="abhi wavhal"

# %%
# Return True if the bridge is safe and False if the bridge is not safe. Hint : Use the find() method
if a.find(" "):
    print("it is false that the bridge is safe bridge ")
else:
    print("it is false that the bridge is  not safe bridge ")
# Out:
# it is false that the bridge is  not safe bridge

# %%
# Fill in the blanks
# Out:
# It is False that the bridge is a safe bridge

# %% [markdown]
# ## <u>Problem 4</u>
#
# Count the number of D's in a string inputted by the user. This will be <b>case insensitive</b>.

# %%
# Store the user input in a variable
user_string = 'Debris was scattered all over the yard in the densest region of Denmark'

# %%
# Store the count of letter D in the inputted string. Note this will be a case insensitive search

z= 'Debris was scattered all over the yard in the densest region of Denmark'
a= z.count("D")
print(a)
# Out:
# 2

# %%
b=z.lower()
print(b)
# Out:
# debris was scattered all over the yard in the densest region of denmark

# %%
b.count("d")
# Out:
# 5

# %%
# Fill in the blanks
print("the total occurence od D in the z is 2 ")
print("the total occurence od d in the z is 5")
# Out:
# the total occurence od D in the z is 2
# the total occurence od d in the z is 5

# %% [markdown]
# ## <u>Problem 5</u>
#
# Check whether a given string is a palindrome. A palindrome is a word, number, phrase, or other sequence of characters which reads the same backward as forward, such as madam, racecar.

# %%
# Store the user input in a variable
a="nitin"
if a==a[::-1]:
    print("it is palindrome")
else:
    print("it is not palindrome")
# Out:
# it is palindrome

# %%
# Print True if a string is a Palindrome else print false
# Out:
# True

# %%
# Out:
# This is True that the given string is Palindrome
