# %% [markdown]
# 1.	Write a Python program to take two numbers as input from the user and display their sum.
# 2.	Calculate and print the midpoint of two numbers entered by the user.
# 3.	Write a Python program to calculate the area of a triangle using the formula: area = 0.5 * base * height.
# 4.	Take three numbers as input from the user and display their product.
# 5.	Take a number as input and display its square and cube.
# 6.	Take two numbers as input and display their quotient and remainder.
# 7.	Take three numbers as input and display their average.
# 8.	Write a Python program to calculate the area of a rectangle using the formula: area = length * width.
# 9.	Take five numbers as input representing marks obtained and total marks.
# Display the percentage.

# %%
a=int(input("enter the number1= "))
b=int(input("enter the number2= "))
c=a+b
print(c)
# Out:
# enter the number1= 965416
# enter the number2= 4716
# 970132

# %%
a=int(input("enter the number1="))
b=int(input("enter the number 2="))
c=(a+b)/2
print(c)
# Out:
# enter the number1=7854965
# enter the number 2=986596
# 4420780.5

# %%
a=int(input("enter the base="))
b=int(input("enter the height="))
c=0.5*a*b
print(c)
# Out:
# enter the base=2
# enter the height=6
# 6.0

# %%
a=int(input("enter the ="))
b=int(input("enter the ="))
c=int(input("enter the numb3="))
d=a*b*c
print(d)
# Out:
# enter the =7
# enter the =8
# enter the numb3=5
# 280

# %%
a=int(input("enter the number1= "))
# b=int(input("enter the number2= "))
c=a*a

d=a*a*a
print(c)
print(d)
# Out:
# enter the number1= 2
# 4
# 8

# %%
a=int(input("enter the number1= "))
b=int(input("enter the number2= "))
c=a/b
d=a%b
print(c)
print(d)
# Out:
# enter the number1= 46
# enter the number2= 3
# 15.333333333333334
# 1

# %%
a=int(input("enter the number1= "))
b=int(input("enter the number2= "))
c=int(input("enter the number3= "))
c=(a+b+c)/3
print(c)
# Out:
# enter the number1= 45
# enter the number2= 74
# enter the number3= 54
# 57.666666666666664

# %%
a=int(input("enter the length= "))
b=int(input("enter the area= "))
c=a*b
print(c)
# Out:
# enter the length= 5
# enter the area= 4
# 20

# %%
a=int(input("enter the number1= "))
b=int(input("enter the number2= "))
c=int(input("enter the number3= "))
d=int(input("enter the number4= "))
e=int(input("enter the number5= "))
total_num=100
f=(a/total_num)*100
g=(b/total_num)*100
h=(c/total_num)*100
i=(d/total_num)*100
j=(e/total_num)*100
print(f)
print(g)
print(h)
print(i)
print(j)
# Out:
# enter the number1= 50
# enter the number2= 25
# enter the number3= 36
# enter the number4= 84
# enter the number5= 16
# 50.0
# 25.0
# 36.0
# 84.0
# 16.0
