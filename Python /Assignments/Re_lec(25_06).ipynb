# %% [markdown]
# Lecture 4 - 9/2/24
# 1. Write a Python program to sum all the elements in a list.
# 2. Write a Python program to find the largest element in a list.
# 3. Write a Python program to count the number of elements in a list.
# 4. Write a Python program to find the average of elements in a list.
# 5. Write a Python program to reverse a list.
# 6. Write a Python program to check if a given element exists in a list.
# 7. Write a Python program to remove duplicate elements from a list.
# 8. Write a Python program to find the second largest element in a list.
# 9. Write a Python program to sort elements in a list in ascending order.
# 10. Write a Python program to merge two lists and sort them.
# 11. Given a nested list nested_list_row = [[1, 2, 3], [4, 5, 6], [7, 8, 9]], how can you access the
#  number 9 from the list? Write a Python program to achieve this.
# 12. Suppose you have a nested list nested_list_column = [[1, 2, 3], [4, 5, 6], [7, 8, 9]], how
#  can you access the number 8 from the list? Write a Python program to achieve this.
# 13. How can you access the number 100 from the nested list
#  nested_list_column = [[1, 2, 3], [4, 5, 6], [7, 8, 9,[1,55,77,100]]?
# 14. How can you access the number 100 from the nested list
#  nested_list_column = [[1, 2, 3], [4, 5, 6], [7, 8, 9, [1,55,77,100]] using negative indexing?

# %% [markdown]
# Write a Python program to sum all the elements in a list.

# %%
my_list=[1,2,3,4,5,6]
print(sum(my_list))
# Out:
# 21

# %% [markdown]
# 2. Write a Python program to find the largest element in a list.

# %%
my_list=[1,2,3,4,5,6]
# max(my_list)
print(max(my_list))
# print(max.my_list)
# Out:
# 6

# %% [markdown]
# Write a Python program to count the number of elements in a list.

# %%
my_list=[1,2,3,4,5,6]
len(my_list)
# print(my_list)
# Out:
# 6

# %% [markdown]
# Write a Python program to find the average of elements in a list.

# %%
my_list=[1,2,3,4,5,6]
sum(my_list)/len(my_list)
# print(a)
# Out:
# 3.5

# %% [markdown]
# Write a Python program to reverse a list.

# %%
my_list.reverse()
print(my_list)
# Out:
# [6, 5, 4, 3, 2, 1]

# %% [markdown]
# Write a Python program to check if a given element exists in a list.

# %%
my_list=[1,2,3,4,5,6]
num=int(input("enter the number ="))
num in my_list
print(num in my_list)
# Out:
# enter the number =6
# True

# %% [markdown]
# Write a Python program to remove duplicate elements from a list.

# %%
my_list=[1,2,3,4,5,6]
my_list=sorted(my_list,reverse=True)
print(my_list)
# Out:
# [6, 5, 4, 3, 2, 1]

# %% [markdown]
# Write a Python program to find the second largest element in a list.

# %%
my_list=[6, 5, 4, 3, 2, 1]
my_list.sort()
print(my_list[-2] )
# Out:
# 5

# %% [markdown]
# Write a Python program to sort elements in a list in ascending order.

# %%
my_list=[6, 5, 4, 3, 2, 1]
my_list.sort()
print(my_list)
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# Write a Python program to merge two lists and sort them.

# %%
my_l1=[6, 5, 4, 3, 2, 1]
my_l2=[6,7,8,9,10]
my_l3=my_l1+my_l2
my_l3.sort()
print(my_l3)
# Out:
# [1, 2, 3, 4, 5, 6, 6, 7, 8, 9, 10]

# %% [markdown]
# 11. Given a nested list nested_list_row = [[1, 2, 3], [4, 5, 6], [7, 8, 9]], how can you access the
#  number 9 from the list? Write a Python program to achieve this.

# %%
nested_list_row = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
print(nested_list_row[-1][-1])
# Out:
# 9

# %% [markdown]
# 12. Suppose you have a nested list nested_list_column = [[1, 2, 3], [4, 5, 6], [7, 8, 9]], how
#  can you access the number 8 from the list? Write a Python program to achieve this.

# %%
nested_list_column = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
print(nested_list_column[-1][1])
# Out:
# 8

# %% [markdown]
# 13. How can you access the number 100 from the nested list
#  nested_list_column = [[1, 2, 3], [4, 5, 6], [7, 8, 9,[1,55,77,100]]?

# %%
nested_list_column = [[1, 2, 3], [4, 5, 6], [7, 8, 9,[1,55,77,100]]]
print(nested_list_column[2][3][3])
# Out:
# 100

# %% [markdown]
# 14. How can you access the number 100 from the nested list
#  nested_list_column = [[1, 2, 3], [4, 5, 6], [7, 8, 9, [1,55,77,100]] using negative indexing?

# %%
nested_list_column = [[1, 2, 3], [4, 5, 6], [7, 8, 9,[1,55,77,100]]]
print(nested_list_column[-1][-1][-1])
# Out:
# 100
