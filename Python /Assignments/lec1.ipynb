# %% [markdown]
# 1.	Write a Python program to take two numbers as input from the user and display their sum.
# 2.	Calculate and print the midpoint of two numbers entered by the user.
# 3.	Write a Python program to calculate the area of a triangle using the formula: area = 0.5 * base * height.
# 4.	Take three numbers as input from the user and display their product.
# 5.	Take a number as input and display its square and cube.
# 6.	Take two numbers as input and display their quotient and remainder.
# 7.	Take three numbers as input and display their average.
# 8.	Write a Python program to calculate the area of a rectangle using the formula: area = length * width.
# 9.	Take five numbers as input representing marks obtained and total marks.
# Display the percentage.

# %% [markdown]
# 1) Write a Python program to take two numbers as input from the user and display their sum.

# %%
num1=int(input("enter the number = "))
num2= int(input ("enter the number= "))
addition= num1+num2
print("two numbers as input from the user and display their sum",addition )
# Out:
# enter the number = 6
# enter the number= 3
# two numbers as input from the user and display their sum 9

# %% [markdown]
# 2)Calculate and print the midpoint of two numbers entered by the user.

# %%
num1=int (input ("enter the number = "  ))
num2 = int (input ("enetr the number= " ))
midpoint= (num1+num2)/2
print ("midpoint of two numbers",midpoint )
# Out:
# enter the number = 5
# enetr the number= 6
# midpoint of two numbers 5.5

# %% [markdown]
# 3)Write a Python program to calculate the area of a triangle using the formula: area = 0.5 * base * height

# %%
num1=int(input("enter the height= "))
num2=int(input ("enter the base= "))
area_of_triangle= num1*num2 *0.5
print("area of triangle ",area_of_triangle)

# %% [markdown]
# 4)Take three numbers as input from the user and display their product.

# %%
num1= int(input("enter the first  number:-  "))
num2= int(input("enter the second number:-  "))
num3= int(input("enter the third  number:-  "))
multiplication= num1*num2*num3
print("product of three numbers is",multiplication)
# Out:
# enter the first  number:-  3
# enter the second number:-  6
# enter the third  number:-  9
# product of three numbers is 162

# %% [markdown]
# 5)Take a number as input and display its square and cube.

# %%
num =int(input("enter the number:- "))
square= num*num
cube = num*num*num

print("number and its square",square)
print("number and its cube ",cube)
# Out:
# enter the number:- 2
# number and its square 4
# number and its cube  8

# %% [markdown]
# 6)Take two numbers as input and display their quotient and remainder.

# %%
num=int(input("enter the number:- "))
quotient=num/num
remainder= num%num
print("quotient of num is  ",quotient )
print ("remainder of num is ", remainder)
# Out:
# enter the number:- 69
# quotient of num is   1.0
# remainder of num is  0

# %% [markdown]
# 7)Take three numbers as input and display their average.

# %%
num1= int(input("enter the number =  "))
num2= int(input("eneter the number=  "))
num3=int(input("eneter the number = " ))
average = (num1+num2+num3)/3
print("three numbers and thier average",average)
# Out:
# enter the number =  9
# eneter the number=  6
# eneter the number = 9
# three numbers and thier average 8.0

# %% [markdown]
# 8)Write a Python program to calculate the area of a rectangle using the formula: area = length * width.

# %%
num1= int(input("enter the length= "))
num2= int(input("enter the width= "))
area= num1*num2
print("area of rectangle",area)
# Out:
# enter the length= 23
# enter the width= 3
# area of rectangle 69

# %% [markdown]
# 9)Take five numbers as input representing marks obtained and total marks. Display the percentage.

# %%
num1= int(input("enter the number = "))
num2= int(input("enter the number = "))
num3= int(input("enter the number = "))
num4= int(input("enter the number = "))
num5= int(input("enter the number = "))
percentage= ((num1+num2+num3+num4+num5)/500)*100
print("percentage of 5 numbers",percentage)
# Out:
# enter the number = 98
# enter the number = 85
# enter the number = 75
# enter the number = 69
# enter the number = 49
# percentage of 5 numbers 75.2
