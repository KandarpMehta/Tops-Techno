# %% [markdown]
# Question 1: Write a Python program that checks whether a given number is positive, negative, or zero. Print the corresponding message.
#
#
# Question 2: Write a Python program that compares two numbers and prints the larger number.
#
#
# Question 3: Write a Python program that checks if a given string is a palindrome or not. Print "Palindrome" if it is, otherwise print "Not a palindrome".
#
#
# Question 4: Write a Python program that determines whether a given character is a vowel or a consonant. Print "Vowel" if it is a vowel, otherwise print "Consonant".
#
#
# Question 5: Write a Python program that assigns a grade to a student based on their exam score. If the score is greater than or equal to 90, assign grade "A"; if it is between 80 and 89, assign grade "B"; if it is between 70 and 79, assign grade "C"; if it is between 60 and 69, assign grade "D"; otherwise, assign grade "F".
#
#
# Question 6: Write a Python program that determines the season based on a given month. If the month is between March and May, print "Spring"; if it is between June and August, print "Summer"; if it is between September and November, print "Autumn"; if it is between December and February, print "Winter".

# %% [markdown]
# check if te number is positive or negative or zero

# %% [markdown]
# Question 1: Write a Python program that checks whether a given number is positive, negative, or zero. Print the corresponding message.

# %%
a= int(input("enter the number="))
if a>0:
  print("positive",a )
if a<0:
 print("negative",a)
if a==0:
  print("zero",a)
# Out:
# enter the number=7
# positive 7

# %% [markdown]
# Question 2: Write a Python program that compares two numbers and prints the larger number.

# %%
a= int(input("enter the number 1 ="))
b= int(input("enter the number 2 ="))
if a>b:
  print("this the the greater number",a)
else :
  print("this the the greater number",b)
# Out:
# enter the number 1 =8741
# enter the number 2 =57452
# this the the greater number 57452

# %% [markdown]
# Question 3: Write a Python program that checks if a given string is a palindrome or not. Print "Palindrome" if it is, otherwise print "Not a palindrome".

# %%
a="nitin"
if a==a[::-1]:
  print("yes its a palindrome",a)
# Out:
# yes its a palindrome nitin

# %% [markdown]
# Question 4: Write a Python program that determines whether a given character is a vowel or a consonant. Print "Vowel" if it is a vowel, otherwise print "Consonant".

# %%
z= input("enter the string=")
vovels ="a,e,i,o,u"
if z in vovels:
 print("vovels",z)
else :
  print("constraints",z)
# Out:
# enter the string=a
# vovels a

# %% [markdown]
# Question 5: Write a Python program that assigns a grade to a student based on their exam score. If the score is greater than or equal to 90, assign grade "A"; if it is between 80 and 89, assign grade "B"; if it is between 70 and 79, assign grade "C"; if it is between 60 and 69, assign grade "D"; otherwise, assign grade "F".

# %%
marks = int(input("enter the number="))
if marks>=90:
 print("A grade",marks)
elif 89>marks>80:
 print("B grade",marks)
elif 79>marks>70:
 print("C grade",marks)
elif 69>marks>60:
 print("D grade",marks)
else:
 print("F grade",marks)
# Out:
# enter the number=8791
# A grade 8791

# %% [markdown]
# Question 6: Write a Python program that determines the season based on a given month. If the month is between March and May, print "Spring"; if it is between June and August, print "Summer"; if it is between September and November, print "Autumn"; if it is between December and February, print "Winter".

# %%
month=input("enter the month number=")
if month in (3,5,6):
 print("Spring")
elif month in (6,7,8):
 print("Summer")
elif month in (9,10,11):
 print("Autumn")
elif month in (12,1,2):
 print("Winter")
else:
 print("invalid season")
# Out:
# enter the month number=7
# invalid season

# %% [markdown]
# Question 1: Write a Python program that checks if a given number is even. If it is, print "Even number".

# %%
a= int(input("enter the number="))
if (a%2==0):
 print("even number",a)
else:
  print("not a even number",a)
# Out:
# enter the number=69
# not a even number 69

# %% [markdown]
# Question 2: Write a Python program that checks if a given string contains the letter 'a'. If it does, print "String contains 'a'".

# %%
string = input("Enter a string ")
if 'a' in string:
  print("a cointains in string")
# Out:
# Enter a string abhi
# a cointains in string

# %% [markdown]
# Question 3: Write a Python program that checks if a given year is a leap year. If it is, print "Leap year".

# %%
a=int(input("enter the year="))
if (a%4==0):
  print("its a leap year",a)
# Out:
# enter the year=2024
# its a leap year 2024

# %% [markdown]
# Question 4: Write a Python program that checks if a given number is positive. If it is, print "Positive number".

# %%
a= int(input("enter the number="))
if a>0:
  print("positive number")
# Out:
# enter the number=544853
# positive number

# %% [markdown]
# Question 5: Write a Python program that checks if a given character is a vowel. If it is, print "Vowel".

# %%
d= input("enter the character=")
if d in ("a,e,i,o,u"):
  print("Vowel",d)
# Out:
# enter the character=m

# %% [markdown]
# Question 6: Write a Python program that checks if a given number is greater than 100. If it is, print "Greater than 100".

# %%
a= int(input("enter the number="))
if (a>100):
  print("greater than 100",a)
else:
  print("error",a)
# Out:
# enter the number=21
# error 21

# %% [markdown]
# Question 7: Write a Python program that checks if a given string is empty. If it is, print "Empty string".

# %%
def check_empty_string(input_string):
    if not input_string:
        print("Empty string")
    else:
        print("String is not empty")

# Example usage:
input_string = input("Enter a string: ")
check_empty_string(input_string)
# Out:
# Enter a string: nasty
# String is not empty

# %% [markdown]
# Question 8: Write a Python program that checks if a given number is divisible by both 5 and 7. If it is, print "Divisible by 5 and 7".

# %%
a=int(input("enter the number="))
if (a%5==0) & (a%7==0):
  print("divisble by 5",a)
  print("divisble by 7",a)
else :
  print("Error")
# Out:
# enter the number=75
# Error

# %% [markdown]
# Question 9: Write a Python program that checks if a given list contains any negative numbers. If it does, print "List contains negative numbers".

# %%
my_list = [1, 3, 4, 6, 7, -5, 0, 9505]

for num in my_list:
    if num > 0:
        print("positive", num)
    else:
        print("Error")
# Out:
# positive 1
# positive 3
# positive 4
# positive 6
# positive 7
# Error
# Error
# positive 9505

# %% [markdown]
# Question 10: Write a Python program that checks if a given word is a palindrome. If it is, print "Palindrome".

# %%
a="racecar"
if a[::-1]==a :
  print("yes its a palindrome ")
else :
  print("not its not a palindrome")
# Out:
# yes its a palindrome

# %% [markdown]
# # ***if-else statements***

# %% [markdown]
# Question 1: Write a Python program that checks if a given number is positive. If it is, print "Positive number"; otherwise, print "Negative number".

# %%
a= int(input("enter the number="))
if a>0:
 print("positive number",a)
else:
  print("negative number",a)
# Out:
# enter the number=69
# positive number 69

# %% [markdown]
# Question 2: Write a Python program that checks if a given string is empty. If it is, print "Empty string"; otherwise, print "Non-empty string".

# %%
def check_empty_string(input_string):
    if not input_string:
        print("Empty string")
    else:
        print("String is not empty")

# Example usage:
input_string = input("Enter a string: ")
check_empty_string(input_string)
# Out:
# Enter a string: nasty
# String is not empty

# %% [markdown]
# Question 3: Write a Python program that checks if a given number is even. If it is, print "Even number"; otherwise, print "Odd number".

# %%
a= int(input("enter the number="))
if (a%2==0):
 print("even number",a)
else:
  print("not a even number",a)
# Out:
# enter the number=69
# not a even number 69

# %% [markdown]
# Question 4: Write a Python program that checks if a given character is a vowel. If it is, print "Vowel"; otherwise, print "Consonant".

# %%
d= input("enter the character=")
if d in ("a,e,i,o,u"):
  print("Vowel",d)
else:
  print("Error")
# Out:
# enter the character=z
# Error

# %% [markdown]
# Question 5: Write a Python program that checks if a given year is a leap year. If it is, print "Leap year"; otherwise, print "Not a leap year".

# %%
a=int(input("enter the year="))
if (a%4==0):
  print("its a leap year:",a)
else:
  print("its not a leap year:",a)
# Out:
# enter the year=687534
# its not a leap year: 687534

# %% [markdown]
# Question 6: Write a Python program that checks if a given number is divisible by 3. If it is, print "Divisible by 3"; otherwise, print "Not divisible by 3".

# %%
a=int(input("enter the number="))
if (a%3==0):
  print("divisble by 3",a)

else :
  print("Not divisible by 3",a)
# Out:
# enter the number=89476352
# Not divisible by 3 89476352

# %% [markdown]
# Question 7: Write a Python program that checks if a given string is a palindrome. If it is, print "Palindrome"; otherwise, print "Not a palindrome".

# %%
d= input("enter the name=")
if d[::-1]==d :
  print("Palindrome",d)
else:
  print("Not a palindrome",d)
# Out:
# enter the name=lasun
# Not a palindrome lasun

# %% [markdown]
# Question 8: Write a Python program that checks if a given list is empty. If it is, print "Empty list"; otherwise, print "Non-empty list".

# %%
a=str(input("enter the string="))
if ("a=(" ")"):
  print("empty string",a)
else:
  print("not empty string",a)
# Out:
# enter the string=
# empty string

# %% [markdown]
# Question 9: Write a Python program that checks if a given number is greater than, less than, or equal to 50. Print the corresponding message.

# %%
num= int(input("enter the number="))
if (num>50):
  print("greater than 50:",num)
elif (num<50):
  print("less than 50:",num)
else :
  print("equals to 50:",num)
# Out:
# enter the number=50
# equals to 50: 50

# %% [markdown]
# Question 10: Write a Python program that checks if a given character is an uppercase letter. If it is, print "Uppercase"; otherwise, print "Lowercase".

# %%
naam= input("enter the name=")
if naam == naam.upper():
 print("UPPERCASE:",naam)
else:
   print("lowercase:",naam)
# Out:
# enter the name=nasty
# lowercase: nasty

# %% [markdown]
# # ***if-elif-else statements:***

# %% [markdown]
# Question 1: Write a Python program that checks if a given number is positive, negative, or zero. Print the corresponding message.

# %%
a= int(input("enter the number="))
if a>0:
 print("positive number",a)
elif a<0:
  print("negative number",a)
else:
  print("equals to zero",a)
# Out:
# enter the number=69
# positive number 69

# %% [markdown]
# Question 2: Write a Python program that compares two numbers and prints the larger number.

# %%
a= int(input("enter the number 1 ="))
b= int(input("enter the number 2 ="))
if a>b:
  print("this the the greater number",a)
else :
  print("this the the greater number",b)
# Out:
# enter the number 1 =9784654
# enter the number 2 =7485454783
# this the the greater number 7485454783

# %% [markdown]
# Question 3: Write a Python program that determines whether a given temperature is hot, warm, or cold. Print the corresponding message.

# %%
num1=int(input("enter the number= "))
if num1>30:
  print("the temperature is hot", num1)
elif 25>num1>10:
  print("the tempoperature is warm ", num1 )
else :
  print("weather is cold", num1 )
# Out:
# enter the number= 69
# the temperature is hot 69

# %% [markdown]
# Question 4: Write a Python program that checks if a given year is a leap year, a century year,
# or neither. Print the corresponding message.

# %%
a =int(input("enter the year="))
if (a%4==0):
  print("its a leap year",a)
else:
  print("its not a leap year",a)
# Out:
# enter the year=2024
# its a leap year 2024

# %% [markdown]
# Question 5: Write a Python program that categorizes a given character into uppercase letter,
# lowercase letter, digit, or special character. Print the corresponding message.

# %%
a = input("enter the str= ")
if a.isupper():
  print("capital string", a)
elif a.islower():
  print("lower string",a)
elif a.isdigit():
  print("digit",a)
else:
  print("error")
# Out:
# enter the str= 65632
# digit 65632

# %% [markdown]
# Question 6: Write a Python program that calculates the discount percentage based on the
# purchase amount. Print the corresponding discount percentage.

# %%
purchase_amount = float(input("Enter the purchase amount: "))

if purchase_amount >= 100000:
    discount_percentage = 40
elif purchase_amount >= 50000:
    discount_percentage = 20
else:
    discount_percentage = 0

print("Discount percentage:", discount_percentage, "%")
# Out:
# Enter the purchase amount: 8954596
# Discount percentage: 40 %

# %% [markdown]
# Question 7: Write a Python program that checks if a given number is divisible by 2, 3, 5, or
# none of them. Print the corresponding message.

# %%
num1=int(input("enter the number="))
a=[2,3,5]
if num1%2==0:
  print("done by 2 ")
elif num1%3==0:
  print("done by 3 ")
elif num1%5==0:
  print("done by 5")
else:
  print("error")
# Out:
# enter the number=55
# done by 5

# %% [markdown]
# Question 8: Write a Python program that determines the grade based on the percentage obtained. Print the corresponding grade.

# %%
marks = float(input("Enter the percentage: "))
if marks >= 90:
    grade = "A"
elif marks >= 80:
    grade = "B"
elif marks >= 70:
    grade = "C"
elif marks >= 60:
    grade = "D"
else:
    grade = "F"
print("Grade:", grade)
# Out:
# Enter the percentage: 75
# Grade: C

# %% [markdown]
# Question 9: Write a Python program that checks if a given number is within a specific range. Print the corresponding message.

# %%
a=int(input("enter the number= "))
if 100>a>0:
  print("the number is in the range")
else:
  print("the number is not in the range")
# Out:
# enter the number= 5965
# the number is not in the range

# %% [markdown]
# Question 10: Write a Python program that checks if a given string is an English word, a number, or a combination of both. Print the corresponding message.

# %%
a=input("enter the word= ")
if a.isalpha():
  print("alphabet")
elif a.isdigit():
  print("digit")
elif a.isalnum():
  print("both")
else:
  print("error")
# Out:
# enter the word= idwhsnk
# alphabet
